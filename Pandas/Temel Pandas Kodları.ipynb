# %%
import pandas as pd

# %%
student=[
{"name": "Ahmet","surname":"Gunes", "email" : "ahmet@gmail.com"},
{"name": "serkan","surname":"mengücek", "email" : "serkan@gmail.com"}

]

# %% [markdown]
# df=pd.DataFrame(student)

# %%
student2={

    "name":["ahmet","mehmet","ayşe"],
    "surname":["demir","balta","celik"],
    "email":["ahmet@gmail.com","mehmet@gmail.com","ayse@gmail.com"]
}

# %%
df=pd.DataFrame(student2)

# %%
df.surname
# Out:
# 0    demir
# 1    balta
# 2    celik
# Name: surname, dtype: object

# %%
df[['name','surname']]
# Out:
#      name surname
# 0   ahmet   demir
# 1  mehmet   balta
# 2    ayşe   celik

# %%
df.columns.tolist()
# Out:
# ['name', 'surname', 'email']

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.iloc[1]
# Out:
# name                 mehmet
# surname               balta
# email      mehmet@gmail.com
# Name: 1, dtype: object

# %%
df.iloc[1]['name']
# Out:
# 'mehmet'

# %%
df.loc[1]
# Out:
# name                 mehmet
# surname               balta
# email      mehmet@gmail.com
# Name: 1, dtype: object

# %%
df.index=df.index+5

# %%
df
# Out:
#      name surname             email
# 5   ahmet   demir   ahmet@gmail.com
# 6  mehmet   balta  mehmet@gmail.com
# 7    ayşe   celik    ayse@gmail.com

# %%
df.iloc[1]
# Out:
# name                 mehmet
# surname               balta
# email      mehmet@gmail.com
# Name: 6, dtype: object

# %%
df.loc[5]
# Out:
# name                 ahmet
# surname              demir
# email      ahmet@gmail.com
# Name: 5, dtype: object

# %%
df.shape
# Out:
# (3, 3)

# %%
df=pd.read_csv("Salary_Data.csv")

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df[df['Gender']=='Male']
# Out:
#        Age Gender    Education Level                    Job Title  \
# 0     32.0   Male         Bachelor's            Software Engineer
# 2     45.0   Male                PhD               Senior Manager
# 4     52.0   Male           Master's                     Director
# 5     29.0   Male         Bachelor's            Marketing Analyst
# 7     31.0   Male         Bachelor's                Sales Manager
# ...    ...    ...                ...                          ...
# 6694  27.0   Male        High School    Digital Marketing Manager
# 6696  28.0   Male                PhD         Sales Representative
# 6698  37.0   Male  Bachelor's Degree  Junior Sales Representative
# 6700  32.0   Male        High School              Sales Associate
# 6702  46.0   Male    Master's Degree            Marketing Manager
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 2                    15.0  150000.0
# 4                    20.0  200000.0
# ...

# %%
df[df['Job Title']=='Software Engineer']
# Out:
#        Age  Gender    Education Level          Job Title  Years of Experience  \
# 0     32.0    Male         Bachelor's  Software Engineer                  5.0
# 376   28.0  Female         Bachelor's  Software Engineer                  3.0
# 380   29.0  Female         Bachelor's  Software Engineer                  4.0
# 384   31.0  Female         Bachelor's  Software Engineer                  6.0
# 388   29.0  Female         Bachelor's  Software Engineer                  4.0
# ...    ...     ...                ...                ...                  ...
# 6191  27.0    Male  Bachelor's Degree  Software Engineer                  3.0
# 6205  27.0    Male  Bachelor's Degree  Software Engineer                  3.0
# 6219  27.0    Male  Bachelor's Degree  Software Engineer                  3.0
# 6233  27.0    Male  Bachelor's Degree  Software Engineer                  3.0
# 6247  27.0    Male  Bachelor's Degree  Software Engineer                  3.0
#
#         Salary
# 0      90000.0
# ...

# %%
df[(df['Job Title']=='Software Engineer')&(df['Gender']=='Male')]
# Out:
#        Age Gender    Education Level          Job Title  Years of Experience  \
# 0     32.0   Male         Bachelor's  Software Engineer                  5.0
# 395   28.0   Male         Bachelor's  Software Engineer                  3.0
# 399   29.0   Male         Bachelor's  Software Engineer                  4.0
# 414   28.0   Male         Bachelor's  Software Engineer                  3.0
# 418   29.0   Male         Bachelor's  Software Engineer                  4.0
# ...    ...    ...                ...                ...                  ...
# 6191  27.0   Male  Bachelor's Degree  Software Engineer                  3.0
# 6205  27.0   Male  Bachelor's Degree  Software Engineer                  3.0
# 6219  27.0   Male  Bachelor's Degree  Software Engineer                  3.0
# 6233  27.0   Male  Bachelor's Degree  Software Engineer                  3.0
# 6247  27.0   Male  Bachelor's Degree  Software Engineer                  3.0
#
#         Salary
# 0      90000.0
# ...

# %%
df[df['Job Title']!='Software Engineer']
# Out:
#        Age  Gender    Education Level              Job Title  \
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# 5     29.0    Male         Bachelor's      Marketing Analyst
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# 5                     2.0   55000.0
# ...

# %%
import numpy as np

# %%
df[df['Job Title'].isin(['Director','Data Analyst','Sales Executive	'])]
# Out:
#        Age  Gender    Education Level     Job Title  Years of Experience  \
# 1     28.0  Female           Master's  Data Analyst                  3.0
# 4     52.0    Male           Master's      Director                 20.0
# 81    41.0  Female           Master's  Data Analyst                 13.0
# 378   27.0  Female         Bachelor's  Data Analyst                  2.0
# 382   25.0  Female           Master's  Data Analyst                  1.0
# ...    ...     ...                ...           ...                  ...
# 3360  34.0    Male    Master's Degree  Data Analyst                  8.0
# 3367  35.0  Female    Master's Degree  Data Analyst                  9.0
# 3374  37.0    Male  Bachelor's Degree  Data Analyst                 11.0
# 3377  34.0    Male    Master's Degree  Data Analyst                  8.0
# 3384  35.0  Female    Master's Degree  Data Analyst                  9.0
#
#         Salary
# 1      65000.0
# 4     200000.0
# 81     80000.0
# 378   110000.0
# ...

# %%
df[df['Job Title'].str.contains('Manager',na=False)]
# Out:
#        Age  Gender    Education Level                         Job Title  \
# 2     45.0    Male                PhD                    Senior Manager
# 6     42.0  Female           Master's                   Product Manager
# 7     31.0    Male         Bachelor's                     Sales Manager
# 11    48.0  Female         Bachelor's                        HR Manager
# 13    40.0  Female           Master's                   Project Manager
# ...    ...     ...                ...                               ...
# 6694  27.0    Male        High School         Digital Marketing Manager
# 6695  33.0  Female  Bachelor's Degree         Content Marketing Manager
# 6697  51.0  Female    Master's Degree  Senior Product Marketing Manager
# 6701  30.0  Female  Bachelor's Degree                 Financial Manager
# 6702  46.0    Male    Master's Degree                 Marketing Manager
#
#       Years of Experience    Salary
# 2                    15.0  150000.0
# ...

# %%
df[df['Age']<=30]
# Out:
#        Age  Gender    Education Level                  Job Title  \
# 1     28.0  Female           Master's               Data Analyst
# 5     29.0    Male         Bachelor's          Marketing Analyst
# 8     26.0  Female         Bachelor's      Marketing Coordinator
# 10    29.0    Male           Master's         Software Developer
# 14    27.0    Male         Bachelor's       Customer Service Rep
# ...    ...     ...                ...                        ...
# 6692  24.0    Male  Bachelor's Degree            Sales Executive
# 6694  27.0    Male        High School  Digital Marketing Manager
# 6696  28.0    Male                PhD       Sales Representative
# 6701  30.0  Female  Bachelor's Degree          Financial Manager
# 6703  26.0  Female        High School            Sales Executive
#
#       Years of Experience   Salary
# 1                     3.0  65000.0
# 5                     2.0  55000.0
# 8                     1.0  45000.0
# 10                    3.0  75000.0
# ...

# %%
df.sort_values('Age')
# Out:
#        Age  Gender Education Level                    Job Title  \
# 5031  21.0  Female     High School  Junior Sales Representative
# 5018  21.0  Female     High School  Junior Sales Representative
# 4923  21.0  Female     High School  Junior Sales Representative
# 5044  21.0  Female     High School  Junior Sales Representative
# 4910  21.0  Female     High School  Junior Sales Representative
# ...    ...     ...             ...                          ...
# 1225  62.0    Male             PhD    Software Engineer Manager
# 1258  62.0    Male             PhD    Software Engineer Manager
# 1236  62.0    Male             PhD    Software Engineer Manager
# 172    NaN     NaN             NaN                          NaN
# 260    NaN     NaN             NaN                          NaN
#
#       Years of Experience    Salary
# 5031                  0.0   25000.0
# 5018                  0.0   25000.0
# 4923                  0.0   25000.0
# 5044                  0.0   25000.0
# ...

# %%
df.sort_values('Age',ascending=False,na_position='first')## na ları başa koyar
# Out:
#        Age  Gender Education Level                    Job Title  \
# 172    NaN     NaN             NaN                          NaN
# 260    NaN     NaN             NaN                          NaN
# 1236  62.0    Male             PhD    Software Engineer Manager
# 1305  62.0    Male             PhD    Software Engineer Manager
# 1304  62.0    Male             PhD    Software Engineer Manager
# ...    ...     ...             ...                          ...
# 5044  21.0  Female     High School  Junior Sales Representative
# 4988  21.0  Female     High School  Junior Sales Representative
# 5057  21.0  Female     High School  Junior Sales Representative
# 5031  21.0  Female     High School  Junior Sales Representative
# 5018  21.0  Female     High School  Junior Sales Representative
#
#       Years of Experience    Salary
# 172                   NaN       NaN
# 260                   NaN       NaN
# 1236                 20.0  200000.0
# 1305                 19.0  200000.0
# ...

# %%
df.sort_values('Age',ascending=False,inplace=True) ## df'yi gucneller

# %%
df
# Out:
#        Age  Gender Education Level                    Job Title  \
# 1236  62.0    Male             PhD    Software Engineer Manager
# 1305  62.0    Male             PhD    Software Engineer Manager
# 1304  62.0    Male             PhD    Software Engineer Manager
# 1258  62.0    Male             PhD    Software Engineer Manager
# 1225  62.0    Male             PhD    Software Engineer Manager
# ...    ...     ...             ...                          ...
# 5057  21.0  Female     High School  Junior Sales Representative
# 5031  21.0  Female     High School  Junior Sales Representative
# 5018  21.0  Female     High School  Junior Sales Representative
# 172    NaN     NaN             NaN                          NaN
# 260    NaN     NaN             NaN                          NaN
#
#       Years of Experience    Salary
# 1236                 20.0  200000.0
# 1305                 19.0  200000.0
# 1304                 20.0  200000.0
# 1258                 19.0  200000.0
# ...

# %%
df.sort_values(['Age','Years of Experience'],ascending=[False,False])
# Out:
#        Age  Gender Education Level                    Job Title  \
# 1236  62.0    Male             PhD    Software Engineer Manager
# 1304  62.0    Male             PhD    Software Engineer Manager
# 1305  62.0    Male             PhD    Software Engineer Manager
# 1258  62.0    Male             PhD    Software Engineer Manager
# 1225  62.0    Male             PhD    Software Engineer Manager
# ...    ...     ...             ...                          ...
# 5057  21.0  Female     High School  Junior Sales Representative
# 5031  21.0  Female     High School  Junior Sales Representative
# 5018  21.0  Female     High School  Junior Sales Representative
# 172    NaN     NaN             NaN                          NaN
# 260    NaN     NaN             NaN                          NaN
#
#       Years of Experience    Salary
# 1236                 20.0  200000.0
# 1304                 20.0  200000.0
# 1305                 19.0  200000.0
# 1258                 19.0  200000.0
# ...

# %%
df=df.sort_index()

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df.nlargest(10,'Salary') ## Salary en yuksek ilk 10 satır
# Out:
#        Age Gender    Education Level                 Job Title  \
# 30    50.0   Male         Bachelor's                       CEO
# 83    52.0   Male                PhD  Chief Technology Officer
# 5001  45.0   Male  Bachelor's Degree         Financial Manager
# 4276  51.0   Male                PhD            Data Scientist
# 4291  51.0   Male                PhD            Data Scientist
# 4306  51.0   Male                PhD            Data Scientist
# 4321  51.0   Male                PhD            Data Scientist
# 4336  51.0   Male                PhD            Data Scientist
# 4351  51.0   Male                PhD            Data Scientist
# 4366  51.0   Male                PhD            Data Scientist
#
#       Years of Experience    Salary
# 30                   25.0  250000.0
# 83                   24.0  250000.0
# 5001                 21.0  250000.0
# 4276                 24.0  240000.0
# 4291                 24.0  240000.0
# 4306                 24.0  240000.0
# ...

# %%
df=df.nsmallest(10,'Salary') ## salary en düşük ilk 10 kişi

# %%
df
# Out:
#        Age  Gender    Education Level                           Job Title  \
# 259   29.0    Male         Bachelor's  Junior Business Operations Analyst
# 4633  31.0  Female  Bachelor's Degree               Junior HR Coordinator
# 1890  25.0  Female  Bachelor's Degree                 Front end Developer
# 2654  23.0    Male                PhD           Software Engineer Manager
# 3893  22.0    Male        High School              Junior Sales Associate
# 3906  29.0  Female        High School              Junior Sales Associate
# 3921  29.0  Female        High School              Junior Sales Associate
# 3936  29.0  Female        High School              Junior Sales Associate
# 3951  29.0  Female        High School              Junior Sales Associate
# 3966  29.0  Female        High School              Junior Sales Associate
#
#       Years of Experience   Salary
# 259                   1.5    350.0
# 4633                  4.0    500.0
# 1890                  1.0    550.0
# ...

# %%
df.reset_index() ## indexleri 0 larama  ekstra index kolonu ekler
# Out:
#    index   Age  Gender    Education Level                           Job Title  \
# 0    259  29.0    Male         Bachelor's  Junior Business Operations Analyst
# 1   4633  31.0  Female  Bachelor's Degree               Junior HR Coordinator
# 2   1890  25.0  Female  Bachelor's Degree                 Front end Developer
# 3   2654  23.0    Male                PhD           Software Engineer Manager
# 4   3893  22.0    Male        High School              Junior Sales Associate
# 5   3906  29.0  Female        High School              Junior Sales Associate
# 6   3921  29.0  Female        High School              Junior Sales Associate
# 7   3936  29.0  Female        High School              Junior Sales Associate
# 8   3951  29.0  Female        High School              Junior Sales Associate
# 9   3966  29.0  Female        High School              Junior Sales Associate
#
#    Years of Experience   Salary
# 0                  1.5    350.0
# 1                  4.0    500.0
# ...

# %%
df.reset_index(drop=True) ## indexleri 0 larama index kolonu eklemez
# Out:
#     Age  Gender    Education Level                           Job Title  \
# 0  29.0    Male         Bachelor's  Junior Business Operations Analyst
# 1  31.0  Female  Bachelor's Degree               Junior HR Coordinator
# 2  25.0  Female  Bachelor's Degree                 Front end Developer
# 3  23.0    Male                PhD           Software Engineer Manager
# 4  22.0    Male        High School              Junior Sales Associate
# 5  29.0  Female        High School              Junior Sales Associate
# 6  29.0  Female        High School              Junior Sales Associate
# 7  29.0  Female        High School              Junior Sales Associate
# 8  29.0  Female        High School              Junior Sales Associate
# 9  29.0  Female        High School              Junior Sales Associate
#
#    Years of Experience   Salary
# 0                  1.5    350.0
# 1                  4.0    500.0
# 2                  1.0    550.0
# 3                  1.0    579.0
# ...

# %%
df=pd.read_csv("Salary_Data.csv")

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df.describe()
# Out:
#                Age  Years of Experience         Salary
# count  6702.000000          6701.000000    6699.000000
# mean     33.620859             8.094687  115326.964771
# std       7.614633             6.059003   52786.183911
# min      21.000000             0.000000     350.000000
# 25%      28.000000             3.000000   70000.000000
# 50%      32.000000             7.000000  115000.000000
# 75%      38.000000            12.000000  160000.000000
# max      62.000000            34.000000  250000.000000

# %%
df.Gender.value_counts() ##Genderdeki Male female sayısı
# Out:
# Gender
# Male      3674
# Female    3014
# Other       14
# Name: count, dtype: int64

# %%
df['Education Level'].value_counts(normalize=True)*100 ## değerlerin yüzdelik dağılımı
# Out:
# Education Level
# Bachelor's Degree    33.830772
# Master's Degree      23.474108
# PhD                  20.414863
# Bachelor's           11.281898
# High School           6.685569
# Master's              4.297866
# phD                   0.014923
# Name: proportion, dtype: float64

# %%
df.Salary.sum()## kolonun verilerini topluyor
# Out:
# np.float64(772575337.0)

# %%
df.groupby('Job Title')['Salary'].mean()
# Out:
# Job Title
# Account Manager              75000.000000
# Accountant                   55000.000000
# Administrative Assistant     50000.000000
# Back end Developer          102352.561475
# Business Analyst             77500.000000
#                                 ...
# UX Designer                  80000.000000
# UX Researcher                65000.000000
# VP of Finance               200000.000000
# VP of Operations            190000.000000
# Web Developer                66436.781609
# Name: Salary, Length: 193, dtype: float64

# %%
##df['Years of Experience'] = df['Years of Experience'].apply(lambda x:x+10) ## kolandaki verileri işlem yapar +10 eklıyor

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df['Years of Experience'] = df['Years of Experience'].apply(lambda x:x+10 if(x>10)else x) ## kolandaki verileri işlem yapar +10 eklıyor

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    25.0  150000.0
# 3                     7.0   60000.0
# 4                    30.0  200000.0
# ...

# %%
df.groupby('Gender').apply(lambda x : int(x['Salary'].mean() / x['Age'].mean()))
# Out:
# C:\Users\serkan\AppData\Local\Temp\ipykernel_14256\2325229148.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('Gender').apply(lambda x : int(x['Salary'].mean() / x['Age'].mean()))
# Gender
# Female    3307
# Male      3527
# Other     3180
# dtype: int64

# %%
df=pd.read_csv('Salary_Data.csv')

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
salary_df=df.groupby('Job Title')['Salary'].mean().reset_index()

# %%
salary_df
# Out:
#                     Job Title         Salary
# 0             Account Manager   75000.000000
# 1                  Accountant   55000.000000
# 2    Administrative Assistant   50000.000000
# 3          Back end Developer  102352.561475
# 4            Business Analyst   77500.000000
# ..                        ...            ...
# 188               UX Designer   80000.000000
# 189             UX Researcher   65000.000000
# 190             VP of Finance  200000.000000
# 191          VP of Operations  190000.000000
# 192             Web Developer   66436.781609
#
# [193 rows x 2 columns]

# %%
salary_df.sort_values('Salary',ascending=False).head(5).plot(x="Job Title",y='Salary') ## plot görselleştirme ye  yarıyor
# Out:
# <Axes: xlabel='Job Title'>

# %%
salary_df.sort_values('Salary',ascending=False).head(5).plot(x="Job Title",y='Salary',kind='bar')
# Out:
# <Axes: xlabel='Job Title'>
